# %% [markdown]
# <p>
# <h1> <font color = 'Blue'> Introduction to Data Visulization using </font> <font color = "red"> "matplotlib" </font> </h1>
# <p>

# %% [markdown]
# You can show matplotlib figures directly in the notebook by using the %matplotlib notebook and %matplotlib inline magic commands.
#
# %matplotlib notebook provides an interactive environment.

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def on_press(event):
    if event.inaxes is None: return
    for line in event.inaxes.lines:
        if event.key=='t':
            visible = line.get_visible()
            line.set_visible(not visible)
    event.inaxes.figure.canvas.draw()

fig, ax = plt.subplots(1)

fig.canvas.mpl_connect('key_press_event', on_press)

ax.plot(np.random.rand(2, 20))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Plotting without scripting layer

# %%
# First let's set the backend without using mpl.use() from the scripting layer
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
import numpy as np

# create a new figure
fig = Figure()

# associate fig with the backend
canvas = FigureCanvasAgg(fig)

# generate 10000 normaly distributed sample points 
x = np.random.randn(10000)

# add a subplot to the fig
ax = fig.add_subplot(1,1,1)

# plot the histogram for x array
ax.hist(x, 100)

# save the figure to histogram.png
ax.set_title("My First Histogram")   # set the title of the plot as "My First Histogram"
fig.savefig('histogram.png')

# %%
from IPython.display import Image
Image("histogram.png")

# %% [markdown]
# ### plotting using scripting layer

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
x = np.random.randn(10000)
plt.hist(x, 100)
plt.title('Normal distribution')
plt.savefig('matplotlib_histogram.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Display a point on a graph

# %%
# create a new figure
plt.figure()

# plot the point (1.5, 1.5) using the circle marker
plt.plot(1.5, 1.5,'ro')
# plot the point (2, 2) using the circle marker
plt.plot(2, 2, 'bo')
# plot the point (2.5, 2.5) using the circle marker
plt.plot(2.5, 2.5, 'go')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Labelling a graph using artist layer

# %%
#get the current axes
ax = plt.gca()

# Set axis properties [xmin, xmax, ymin, ymax]
ax.axis([0,6,0,10])
ax.set_title("My first graph")
ax.set_xlabel("x - axis")
ax.set_ylabel("y - axis")

# get the information about each artist layer instance
ax.get_children()

# get the details of an instance
ax.get_xaxis().get_children()
# Out:
# [Text(0.5,23.5222,'x - axis'),
#  Text(1,24.9111,''),
# ...

# %% [markdown]
# ### Labelling using Scripting layer

# %%
plt.axis([0,4,0,5])
plt.title('Labelled using plt')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
# Out:
# Text(47.0972,0.5,'Y - Axis')

# %% [markdown]
# ## Basic Plots using Matplotlib

# %%
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 1. Scatter Plots

# %%
plt.figure()
plt.scatter(iris['petal_width'], iris['petal_length'],s=50, c='red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# changing the size and color of the points based on species
plt.figure()
sp1 = iris[iris['species']=='setosa']
sp2 = iris[iris['species']=='virginica']
sp3 = iris[iris['species']=='versicolor']
plt.scatter(sp1['petal_width'], sp1['petal_length'], s= 25, c='red', label = 'setosa')
plt.scatter(sp2['petal_width'], sp2['petal_length'], s= 25, c='blue', label = 'virginica')
plt.scatter(sp3['petal_width'], sp3['petal_length'], s= 25, c='green', label = 'versicolor')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title('Petal Width vs Petal Length (Iris Dataset)')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.legend(['S','Vi','Ver'])

# %% [markdown]
# ## Line Plot

# %%
plt.figure()
plt.plot(iris['petal_width'],'r-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(iris['petal_width'],'r-', iris['petal_length'],'b-')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# ## Bar Chart

# %%
plt.figure()
plt.bar(iris['species'],iris['petal_width'], width = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 150 artists>

# %%
plt.figure()
plt.bar(1,sp1['petal_width'], width = 0.3)
plt.bar(2,sp2['petal_width'], width = 0.3)
plt.bar(3,sp3['petal_width'], width = 0.3)
plt.legend(['setosa','virginica','versicolor'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.barh(1,sp1['petal_width'], height = 0.3)
plt.barh(2,sp2['petal_width'], height = 0.3)
plt.barh(3,sp3['petal_width'], height = 0.3)
plt.legend(['setosa','virginica','versicolor'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Histograms

# %%
plt.figure(figsize=(5,5))
plt.hist(iris['petal_width'],bins=30);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ## Box Plots

# %%
plt.figure()
plt.boxplot(iris['sepal_width']);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.boxplot([iris['sepal_width'],iris['sepal_length'],iris['petal_width'],iris['petal_length']]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Subplots

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)
plt.scatter(iris['petal_width'], iris['petal_length'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1, 2, 2)
plt.hist(iris['petal_width'],bins=30);

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.scatter(iris['petal_width'], iris['petal_length'])
# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.hist(iris['petal_width'],bins=30);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# create 2x2 grid of axis subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

# draw n = 10, 100, 1000, and 10000 samples from the normal distribution and plot corresponding histograms
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

# %%
# use gridspec to partition the figure into subplots
plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X, Y)
top_histogram.hist(X, bins=100)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal')
side_histogram.invert_xaxis()

# %%
plt.clf()
